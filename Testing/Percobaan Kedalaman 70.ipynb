# %%
import pandas as pd
import io
 
df = pd.read_csv('/Users/muhammadrezapulungan/Documents/Skripsi/CleanData2.csv', sep=',')
df.head()

X = df['clean_stem']
y = df['label']

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1)


tf_idf = TfidfVectorizer()

X_train = tf_idf.fit_transform(X_train)
X_test = tf_idf.transform(X_test)

print("TF-IDF ", type(X_train), X_train.shape)
# Out:
# TF-IDF  <class 'scipy.sparse.csr.csr_matrix'> (921, 1655)

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 70)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report1 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[19 10  4]
#  [ 6 18 10]
#  [ 5  4 27]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.63      0.58      0.60        33
#            0       0.56      0.53      0.55        34
#            1       0.66      0.75      0.70        36
#
#     accuracy                           0.62       103
#    macro avg       0.62      0.62      0.62       103
# weighted avg       0.62      0.62      0.62       103
#
#
#
# Hasil K-fold
# [0.64516129 0.7173913  0.70652174 0.61956522 0.70652174 0.63043478
#  0.64130435 0.61956522 0.55434783 0.61956522]
#
#
# Rata-rata Akurasi
# 0.6460378681626929

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 70)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report2 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[20  9  4]
#  [ 5 19 10]
#  [ 5  5 26]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.67      0.61      0.63        33
#            0       0.58      0.56      0.57        34
#            1       0.65      0.72      0.68        36
#
#     accuracy                           0.63       103
#    macro avg       0.63      0.63      0.63       103
# weighted avg       0.63      0.63      0.63       103
#
#
#
# Hasil K-fold
# [0.6344086  0.7173913  0.72826087 0.59782609 0.70652174 0.61956522
#  0.68478261 0.65217391 0.52173913 0.63043478]
#
#
# Rata-rata Akurasi
# 0.649310425432445

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 70)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report3 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[20  9  4]
#  [ 7 18  9]
#  [ 5  5 26]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.62      0.61      0.62        33
#            0       0.56      0.53      0.55        34
#            1       0.67      0.72      0.69        36
#
#     accuracy                           0.62       103
#    macro avg       0.62      0.62      0.62       103
# weighted avg       0.62      0.62      0.62       103
#
#
#
# Hasil K-fold
# [0.62365591 0.7173913  0.72826087 0.58695652 0.72826087 0.63043478
#  0.67391304 0.67391304 0.52173913 0.64130435]
#
#
# Rata-rata Akurasi
# 0.6525829827021973

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 70)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report4 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[20  9  4]
#  [ 5 18 11]
#  [ 4  4 28]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.69      0.61      0.65        33
#            0       0.58      0.53      0.55        34
#            1       0.65      0.78      0.71        36
#
#     accuracy                           0.64       103
#    macro avg       0.64      0.64      0.64       103
# weighted avg       0.64      0.64      0.64       103
#
#
#
# Hasil K-fold
# [0.66666667 0.67391304 0.72826087 0.61956522 0.69565217 0.63043478
#  0.69565217 0.63043478 0.54347826 0.63043478]
#
#
# Rata-rata Akurasi
# 0.6514492753623189

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 70)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report5 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[20  9  4]
#  [ 6 18 10]
#  [ 5  5 26]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.65      0.61      0.62        33
#            0       0.56      0.53      0.55        34
#            1       0.65      0.72      0.68        36
#
#     accuracy                           0.62       103
#    macro avg       0.62      0.62      0.62       103
# weighted avg       0.62      0.62      0.62       103
#
#
#
# Hasil K-fold
# [0.65591398 0.66304348 0.7173913  0.59782609 0.70652174 0.63043478
#  0.68478261 0.64130435 0.52173913 0.61956522]
#
#
# Rata-rata Akurasi
# 0.6438522674146797

# %%
dfhasil1 = pd.DataFrame(report1).transpose()
dfhasil2 = pd.DataFrame(report2).transpose()
dfhasil3 = pd.DataFrame(report3).transpose()
dfhasil4 = pd.DataFrame(report4).transpose()
dfhasil5 = pd.DataFrame(report5).transpose()

dfhasil1.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil1.xlsx' ,index = False)
dfhasil2.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil2.xlsx' ,index = False)
dfhasil3.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil3.xlsx' ,index = False)
dfhasil4.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil4.xlsx' ,index = False)
dfhasil5.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil5.xlsx' ,index = False)
