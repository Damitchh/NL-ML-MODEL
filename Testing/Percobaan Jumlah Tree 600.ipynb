# %%
import pandas as pd
import io
 
df = pd.read_csv('/Users/muhammadrezapulungan/Documents/Skripsi/CleanData2.csv', sep=',')
df.head()

X = df['clean_stem']
y = df['label']

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1)


tf_idf = TfidfVectorizer()

X_train = tf_idf.fit_transform(X_train)
X_test = tf_idf.transform(X_test)

print("TF-IDF ", type(X_train), X_train.shape)
# Out:
# TF-IDF  <class 'scipy.sparse.csr.csr_matrix'> (921, 1624)

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 600, max_depth = 60)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report1 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[22 10  1]
#  [10 12  2]
#  [13  6 27]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.49      0.67      0.56        33
#            0       0.43      0.50      0.46        24
#            1       0.90      0.59      0.71        46
#
#     accuracy                           0.59       103
#    macro avg       0.61      0.58      0.58       103
# weighted avg       0.66      0.59      0.61       103
#
#
#
# Hasil K-fold
# [0.68817204 0.59782609 0.61956522 0.65217391 0.66304348 0.65217391
#  0.64130435 0.64130435 0.61956522 0.66304348]
#
#
# Rata-rata Akurasi
# 0.6438172043010753

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 600, max_depth = 60)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report2 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[21 11  1]
#  [ 9 14  1]
#  [13  6 27]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.49      0.64      0.55        33
#            0       0.45      0.58      0.51        24
#            1       0.93      0.59      0.72        46
#
#     accuracy                           0.60       103
#    macro avg       0.62      0.60      0.59       103
# weighted avg       0.68      0.60      0.62       103
#
#
#
# Hasil K-fold
# [0.67741935 0.59782609 0.65217391 0.65217391 0.65217391 0.64130435
#  0.64130435 0.63043478 0.61956522 0.66304348]
#
#
# Rata-rata Akurasi
# 0.642741935483871

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 600, max_depth = 60)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report3 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[23 10  0]
#  [ 9 13  2]
#  [13  6 27]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.51      0.70      0.59        33
#            0       0.45      0.54      0.49        24
#            1       0.93      0.59      0.72        46
#
#     accuracy                           0.61       103
#    macro avg       0.63      0.61      0.60       103
# weighted avg       0.68      0.61      0.62       103
#
#
#
# Hasil K-fold
# [0.69892473 0.63043478 0.63043478 0.66304348 0.66304348 0.67391304
#  0.59782609 0.61956522 0.63043478 0.64130435]
#
#
# Rata-rata Akurasi
# 0.6448924731182795

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 600, max_depth = 60)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report4 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[22 10  1]
#  [ 9 13  2]
#  [13  6 27]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.50      0.67      0.57        33
#            0       0.45      0.54      0.49        24
#            1       0.90      0.59      0.71        46
#
#     accuracy                           0.60       103
#    macro avg       0.62      0.60      0.59       103
# weighted avg       0.67      0.60      0.61       103
#
#
#
# Hasil K-fold
# [0.70967742 0.59782609 0.65217391 0.69565217 0.66304348 0.65217391
#  0.63043478 0.65217391 0.58695652 0.67391304]
#
#
# Rata-rata Akurasi
# 0.6514025245441795

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 600, max_depth = 60)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report5 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[21 12  0]
#  [ 8 14  2]
#  [13  6 27]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.50      0.64      0.56        33
#            0       0.44      0.58      0.50        24
#            1       0.93      0.59      0.72        46
#
#     accuracy                           0.60       103
#    macro avg       0.62      0.60      0.59       103
# weighted avg       0.68      0.60      0.62       103
#
#
#
# Hasil K-fold
# [0.68817204 0.60869565 0.64130435 0.67391304 0.65217391 0.65217391
#  0.67391304 0.63043478 0.58695652 0.65217391]
#
#
# Rata-rata Akurasi
# 0.6459911173445536

# %%
dfhasil1 = pd.DataFrame(report1).transpose()
dfhasil2 = pd.DataFrame(report2).transpose()
dfhasil3 = pd.DataFrame(report3).transpose()
dfhasil4 = pd.DataFrame(report4).transpose()
dfhasil5 = pd.DataFrame(report5).transpose()

dfhasil1.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil1.xlsx' ,index = False)
dfhasil2.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil2.xlsx' ,index = False)
dfhasil3.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil3.xlsx' ,index = False)
dfhasil4.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil4.xlsx' ,index = False)
dfhasil5.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil5.xlsx' ,index = False)
