# %%
import pandas as pd
import io
 
df = pd.read_csv('/Users/muhammadrezapulungan/Documents/Skripsi/CleanData2.csv', sep=',')
df.head()

X = df['clean_stem']
y = df['label']

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1)


tf_idf = TfidfVectorizer()

X_train = tf_idf.fit_transform(X_train)
X_test = tf_idf.transform(X_test)

print("TF-IDF ", type(X_train), X_train.shape)
# Out:
# TF-IDF  <class 'scipy.sparse.csr.csr_matrix'> (921, 1595)

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 55)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report1 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[27  3  5]
#  [ 5 20  5]
#  [ 9  5 24]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.66      0.77      0.71        35
#            0       0.71      0.67      0.69        30
#            1       0.71      0.63      0.67        38
#
#     accuracy                           0.69       103
#    macro avg       0.69      0.69      0.69       103
# weighted avg       0.69      0.69      0.69       103
#
#
#
# Hasil K-fold
# [0.6344086  0.56521739 0.5326087  0.63043478 0.65217391 0.64130435
#  0.68478261 0.69565217 0.57608696 0.68478261]
#
#
# Rata-rata Akurasi
# 0.6297452080411408

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 55)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report2 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[27  3  5]
#  [ 8 19  3]
#  [ 8  6 24]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.63      0.77      0.69        35
#            0       0.68      0.63      0.66        30
#            1       0.75      0.63      0.69        38
#
#     accuracy                           0.68       103
#    macro avg       0.69      0.68      0.68       103
# weighted avg       0.69      0.68      0.68       103
#
#
#
# Hasil K-fold
# [0.62365591 0.57608696 0.54347826 0.66304348 0.65217391 0.57608696
#  0.63043478 0.70652174 0.60869565 0.70652174]
#
#
# Rata-rata Akurasi
# 0.6286699392239363

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 55)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report3 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[26  4  5]
#  [ 7 18  5]
#  [ 9  5 24]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.62      0.74      0.68        35
#            0       0.67      0.60      0.63        30
#            1       0.71      0.63      0.67        38
#
#     accuracy                           0.66       103
#    macro avg       0.66      0.66      0.66       103
# weighted avg       0.66      0.66      0.66       103
#
#
#
# Hasil K-fold
# [0.61290323 0.59782609 0.54347826 0.67391304 0.66304348 0.64130435
#  0.67391304 0.68478261 0.59782609 0.66304348]
#
#
# Rata-rata Akurasi
# 0.6352033660589059

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 55)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report4 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[28  3  4]
#  [ 8 17  5]
#  [ 7  7 24]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.65      0.80      0.72        35
#            0       0.63      0.57      0.60        30
#            1       0.73      0.63      0.68        38
#
#     accuracy                           0.67       103
#    macro avg       0.67      0.67      0.66       103
# weighted avg       0.67      0.67      0.67       103
#
#
#
# Hasil K-fold
# [0.6344086  0.58695652 0.55434783 0.66304348 0.66304348 0.59782609
#  0.66304348 0.69565217 0.56521739 0.69565217]
#
#
# Rata-rata Akurasi
# 0.6319191210846189

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 55)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report5 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[26  3  6]
#  [ 5 19  6]
#  [ 5  6 27]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.72      0.74      0.73        35
#            0       0.68      0.63      0.66        30
#            1       0.69      0.71      0.70        38
#
#     accuracy                           0.70       103
#    macro avg       0.70      0.70      0.70       103
# weighted avg       0.70      0.70      0.70       103
#
#
#
# Hasil K-fold
# [0.6344086  0.58695652 0.55434783 0.66304348 0.65217391 0.64130435
#  0.66304348 0.69565217 0.59782609 0.69565217]
#
#
# Rata-rata Akurasi
# 0.6384408602150538

# %%
dfhasil1 = pd.DataFrame(report1).transpose()
dfhasil2 = pd.DataFrame(report2).transpose()
dfhasil3 = pd.DataFrame(report3).transpose()
dfhasil4 = pd.DataFrame(report4).transpose()
dfhasil5 = pd.DataFrame(report5).transpose()

dfhasil1.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil1.xlsx' ,index = False)
dfhasil2.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil2.xlsx' ,index = False)
dfhasil3.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil3.xlsx' ,index = False)
dfhasil4.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil4.xlsx' ,index = False)
dfhasil5.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil5.xlsx' ,index = False)
