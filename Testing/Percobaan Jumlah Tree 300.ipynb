# %%
import pandas as pd
import io
 
df = pd.read_csv('/Users/muhammadrezapulungan/Documents/Skripsi/CleanData2.csv', sep=',')
df.head()

X = df['clean_stem']
y = df['label']

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1)


tf_idf = TfidfVectorizer()

X_train = tf_idf.fit_transform(X_train)
X_test = tf_idf.transform(X_test)

print("TF-IDF ", type(X_train), X_train.shape)
# Out:
# TF-IDF  <class 'scipy.sparse.csr.csr_matrix'> (921, 1613)

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 60)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report1 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[25  8  4]
#  [13 15  1]
#  [ 8  3 26]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.54      0.68      0.60        37
#            0       0.58      0.52      0.55        29
#            1       0.84      0.70      0.76        37
#
#     accuracy                           0.64       103
#    macro avg       0.65      0.63      0.64       103
# weighted avg       0.66      0.64      0.64       103
#
#
#
# Hasil K-fold
# [0.58064516 0.70652174 0.64130435 0.65217391 0.66304348 0.69565217
#  0.61956522 0.66304348 0.66304348 0.54347826]
#
#
# Rata-rata Akurasi
# 0.6428471248246844

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 60)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report2 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[24 11  2]
#  [11 13  5]
#  [ 4  3 30]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.62      0.65      0.63        37
#            0       0.48      0.45      0.46        29
#            1       0.81      0.81      0.81        37
#
#     accuracy                           0.65       103
#    macro avg       0.64      0.64      0.64       103
# weighted avg       0.65      0.65      0.65       103
#
#
#
# Hasil K-fold
# [0.6344086  0.72826087 0.65217391 0.65217391 0.66304348 0.65217391
#  0.61956522 0.61956522 0.60869565 0.57608696]
#
#
# Rata-rata Akurasi
# 0.640614773258532

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 60)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report3 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[26  8  3]
#  [14 13  2]
#  [ 9  3 25]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.53      0.70      0.60        37
#            0       0.54      0.45      0.49        29
#            1       0.83      0.68      0.75        37
#
#     accuracy                           0.62       103
#    macro avg       0.64      0.61      0.61       103
# weighted avg       0.64      0.62      0.62       103
#
#
#
# Hasil K-fold
# [0.59139785 0.68478261 0.67391304 0.63043478 0.65217391 0.67391304
#  0.61956522 0.61956522 0.64130435 0.56521739]
#
#
# Rata-rata Akurasi
# 0.6352267414679756

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 60)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report4 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[27  8  2]
#  [11 14  4]
#  [ 4  3 30]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.64      0.73      0.68        37
#            0       0.56      0.48      0.52        29
#            1       0.83      0.81      0.82        37
#
#     accuracy                           0.69       103
#    macro avg       0.68      0.67      0.67       103
# weighted avg       0.69      0.69      0.69       103
#
#
#
# Hasil K-fold
# [0.58064516 0.68478261 0.66304348 0.67391304 0.65217391 0.67391304
#  0.64130435 0.64130435 0.65217391 0.57608696]
#
#
# Rata-rata Akurasi
# 0.6439340813464236

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 60)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report5 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[25  9  3]
#  [13 15  1]
#  [ 5  3 29]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.58      0.68      0.63        37
#            0       0.56      0.52      0.54        29
#            1       0.88      0.78      0.83        37
#
#     accuracy                           0.67       103
#    macro avg       0.67      0.66      0.66       103
# weighted avg       0.68      0.67      0.67       103
#
#
#
# Hasil K-fold
# [0.64516129 0.68478261 0.65217391 0.64130435 0.67391304 0.70652174
#  0.60869565 0.64130435 0.61956522 0.59782609]
#
#
# Rata-rata Akurasi
# 0.647124824684432

# %%
dfhasil1 = pd.DataFrame(report1).transpose()
dfhasil2 = pd.DataFrame(report2).transpose()
dfhasil3 = pd.DataFrame(report3).transpose()
dfhasil4 = pd.DataFrame(report4).transpose()
dfhasil5 = pd.DataFrame(report5).transpose()

dfhasil1.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil1.xlsx' ,index = False)
dfhasil2.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil2.xlsx' ,index = False)
dfhasil3.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil3.xlsx' ,index = False)
dfhasil4.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil4.xlsx' ,index = False)
dfhasil5.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil5.xlsx' ,index = False)
