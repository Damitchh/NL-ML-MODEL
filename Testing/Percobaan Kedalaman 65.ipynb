# %%
import pandas as pd
import io
 
df = pd.read_csv('/Users/muhammadrezapulungan/Documents/Skripsi/CleanData2.csv', sep=',')
df.head()

X = df['clean_stem']
y = df['label']

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1)


tf_idf = TfidfVectorizer()

X_train = tf_idf.fit_transform(X_train)
X_test = tf_idf.transform(X_test)

print("TF-IDF ", type(X_train), X_train.shape)
# Out:
# TF-IDF  <class 'scipy.sparse.csr.csr_matrix'> (921, 1619)

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 65)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report1 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[18  8  5]
#  [11 23  6]
#  [ 3  2 27]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.56      0.58      0.57        31
#            0       0.70      0.57      0.63        40
#            1       0.71      0.84      0.77        32
#
#     accuracy                           0.66       103
#    macro avg       0.66      0.67      0.66       103
# weighted avg       0.66      0.66      0.66       103
#
#
#
# Hasil K-fold
# [0.6344086  0.60869565 0.59782609 0.63043478 0.70652174 0.7173913
#  0.61956522 0.65217391 0.63043478 0.61956522]
#
#
# Rata-rata Akurasi
# 0.6417017297802712

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 65)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report2 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[18  8  5]
#  [12 22  6]
#  [ 3  2 27]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.55      0.58      0.56        31
#            0       0.69      0.55      0.61        40
#            1       0.71      0.84      0.77        32
#
#     accuracy                           0.65       103
#    macro avg       0.65      0.66      0.65       103
# weighted avg       0.65      0.65      0.65       103
#
#
#
# Hasil K-fold
# [0.60215054 0.61956522 0.61956522 0.65217391 0.7173913  0.7173913
#  0.61956522 0.64130435 0.63043478 0.60869565]
#
#
# Rata-rata Akurasi
# 0.6428237494156147

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 65)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report3 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[18  8  5]
#  [13 21  6]
#  [ 3  3 26]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.53      0.58      0.55        31
#            0       0.66      0.53      0.58        40
#            1       0.70      0.81      0.75        32
#
#     accuracy                           0.63       103
#    macro avg       0.63      0.64      0.63       103
# weighted avg       0.63      0.63      0.63       103
#
#
#
# Hasil K-fold
# [0.62365591 0.60869565 0.59782609 0.66304348 0.69565217 0.70652174
#  0.68478261 0.63043478 0.66304348 0.59782609]
#
#
# Rata-rata Akurasi
# 0.6471482000935016

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 65)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report4 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[18  8  5]
#  [13 21  6]
#  [ 5  1 26]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.50      0.58      0.54        31
#            0       0.70      0.53      0.60        40
#            1       0.70      0.81      0.75        32
#
#     accuracy                           0.63       103
#    macro avg       0.63      0.64      0.63       103
# weighted avg       0.64      0.63      0.63       103
#
#
#
# Hasil K-fold
# [0.61290323 0.61956522 0.55434783 0.64130435 0.70652174 0.69565217
#  0.67391304 0.66304348 0.61956522 0.61956522]
#
#
# Rata-rata Akurasi
# 0.6406381486676017

# %%
# import treeplot
from sklearn.ensemble import RandomForestClassifier

classifier = RandomForestClassifier(n_estimators = 300, max_depth = 65)
classifier.fit(X_train,y_train)

from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

Y_Pred = classifier.predict(X_test)

classifier_cv_score = cross_val_score(classifier, X_train, y_train, cv=10, scoring = 'accuracy')
print("Hasil Confusion Matrix")
print(confusion_matrix(y_test, Y_Pred))
print('\n')
print("Hasil Klasifikasi")
report5 = classification_report(y_test, Y_Pred, output_dict=True)
print(classification_report(y_test, Y_Pred))
print('\n')
print("Hasil K-fold")
print(classifier_cv_score)
kfoldreport1 = classifier_cv_score
print('\n')
print("Rata-rata Akurasi")
print(classifier_cv_score.mean())
# Out:
# Hasil Confusion Matrix
# [[18  8  5]
#  [13 21  6]
#  [ 4  2 26]]
#
#
# Hasil Klasifikasi
#               precision    recall  f1-score   support
#
#           -1       0.51      0.58      0.55        31
#            0       0.68      0.53      0.59        40
#            1       0.70      0.81      0.75        32
#
#     accuracy                           0.63       103
#    macro avg       0.63      0.64      0.63       103
# weighted avg       0.64      0.63      0.63       103
#
#
#
# Hasil K-fold
# [0.64516129 0.59782609 0.60869565 0.63043478 0.7173913  0.72826087
#  0.66304348 0.65217391 0.63043478 0.57608696]
#
#
# Rata-rata Akurasi
# 0.6449509116409538

# %%
dfhasil1 = pd.DataFrame(report1).transpose()
dfhasil2 = pd.DataFrame(report2).transpose()
dfhasil3 = pd.DataFrame(report3).transpose()
dfhasil4 = pd.DataFrame(report4).transpose()
dfhasil5 = pd.DataFrame(report5).transpose()

dfhasil1.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil1.xlsx' ,index = False)
dfhasil2.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil2.xlsx' ,index = False)
dfhasil3.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil3.xlsx' ,index = False)
dfhasil4.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil4.xlsx' ,index = False)
dfhasil5.to_excel('/Users/muhammadrezapulungan/Documents/Skripsi/kedalamantree/hasil5.xlsx' ,index = False)
